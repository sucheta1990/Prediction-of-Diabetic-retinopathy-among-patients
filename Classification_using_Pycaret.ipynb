# %%
import pandas as pd

# %%
df=pd.read_csv('cleaned_pronostico_dataset.csv')

# %%
df.head()
# Out:
#    ID        age  systolic_bp  diastolic_bp  cholesterol    prognosis
# 0   0  77.196340    85.288742     80.021878    79.957109  retinopathy
# 1   1  63.529850    99.379736     84.852361   110.382411  retinopathy
# 2   2  69.003986   111.349455    109.850616   100.828246  retinopathy
# 3   3  82.638210    95.056128     79.666851    87.066303  retinopathy
# 4   4  78.346286   109.154591     90.713220    92.511770  retinopathy

# %%
from pycaret.classification import *

# %%
clf=setup(data=df,target='prognosis')
# Out:
# <style type="text/css">
# #T_cd2d7_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cd2d7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd2d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd2d7_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_cd2d7_row0_col1" class="data row0 col1" >2221</td>
#     </tr>
#     <tr>
#       <th id="T_cd2d7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd2d7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cd2d7_row1_col1" class="data row1 col1" >prognosis</td>
#     </tr>
#     <tr>
#       <th id="T_cd2d7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cd2d7_row2_col0" class="data row2 col0" >Target Type</td>
# ...

# %%
clf
# Out:
# (<MLUsecase.CLASSIFICATION: 1>,
#  True,
#  {'parameter': 'Hyperparameters',
#   'auc': 'AUC',
#   'confusion_matrix': 'Confusion Matrix',
#   'threshold': 'Threshold',
#   'pr': 'Precision Recall',
#   'error': 'Prediction Error',
#   'class_report': 'Class Report',
#   'rfe': 'Feature Selection',
#   'learning': 'Learning Curve',
#   'manifold': 'Manifold Learning',
#   'calibration': 'Calibration Curve',
#   'vc': 'Validation Curve',
#   'dimension': 'Dimensions',
#   'feature': 'Feature Importance',
#   'feature_all': 'Feature Importance (All)',
#   'boundary': 'Decision Boundary',
#   'lift': 'Lift Chart',
#   'gain': 'Gain Chart',
#   'tree': 'Decision Tree',
#   'ks': 'KS Statistic Plot'},
# ...
#                                       Model  Accuracy     AUC  Recall   Prec.  \
#   ridge                    Ridge Classifier    0.7471  0.0000  0.7343  0.7646
#   lda          Linear Discriminant Analysis    0.7471  0.8263  0.7343  0.7646
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_b6372_ th {
#   text-align: left;
# }
# ...

# %% [markdown]
# ## After comparing models can see that ridge classifier is giving better accuracy.

# %% [markdown]
# ### Ridge Model

# %%
ridge_clf=create_model('ridge')
# Out:
# <style type="text/css">
# #T_915ce_row10_col0, #T_915ce_row10_col1, #T_915ce_row10_col2, #T_915ce_row10_col3, #T_915ce_row10_col4, #T_915ce_row10_col5, #T_915ce_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_915ce_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...

# %% [markdown]
# ## Model Tuning

# %%
tuned_model=tune_model(ridge_clf ,n_iter=50, optimize='Accuracy')
# Out:
# <style type="text/css">
# #T_f9c74_row10_col0, #T_f9c74_row10_col1, #T_f9c74_row10_col2, #T_f9c74_row10_col3, #T_f9c74_row10_col4, #T_f9c74_row10_col5, #T_f9c74_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f9c74_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
# ...
